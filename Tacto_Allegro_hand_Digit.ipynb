# %% [markdown]
# # TACTO - Simulator for High-Resolution Vision-based Tactile Sensors
# ## Meta AI : https://github.com/facebookresearch/tacto
# Tested on:
# * Ubuntu 18.04
# * Python 3.8
# * Nvidia GPU (CUDA)

# %% [markdown]
# ## Installation
#
# ```
# git clone https://github.com/facebookresearch/tacto.git
# cd tacto
# pip install -e .
# ```

# %% [markdown]
# ## Digit optic sensor with Allegro hand

# %% [markdown]
# ![screen4.png](attachment:screen4.png)

# %%
# %%bash
# cd <Path>/tacto/examples
# python demo_pybullet_allegro_hand.py

# %% [markdown]
# ## Digit sensor alone

# %% [markdown]
# ![screen5.png](attachment:screen5.png)

# %%
# %%bash
# cd <Path>/tacto/examples
# python demo_pybullet_digit.py
